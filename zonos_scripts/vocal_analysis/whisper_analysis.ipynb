# %%
from transformers import WhisperProcessor, WhisperForConditionalGeneration
import torch
import librosa
import os
import glob
from tqdm import tqdm # เพิ่ม tqdm เพื่อทำ progress bar สวยๆ
import json

# --- 1. Load the Model (เหมือนเดิม) ---
print("Loading Whisper model...")
processor = WhisperProcessor.from_pretrained("cahya/whisper-large-audio-captioning-v1.0")
model = WhisperForConditionalGeneration.from_pretrained("cahya/whisper-large-audio-captioning-v1.0")
print("Model loaded successfully!")


# --- 2. Find All Audio Files (ส่วนอัปเกรด) ---
# ระบุที่อยู่ของ 'ห้องอัดเสียง' ของเรา
audio_folder_path = "../final_audio_output_final/"

# ใช้ glob เพื่อสร้าง 'เพลย์ลิสต์' ของไฟล์ .wav ทั้งหมด
# os.path.join() จะช่วยเชื่อมต่อ path ให้ถูกต้อง
wav_files = glob.glob(os.path.join(audio_folder_path, "*.wav"))
print(f"Found {len(wav_files)} audio files to process in '{audio_folder_path}'")


# --- 3. Process Each File in a Loop (ส่วนอัปเกรด) ---
# สร้าง list ว่างๆ เพื่อเก็บผลลัพธ์
results = []

# ใช้ tqdm ครอบเพลย์ลิสต์ของเราเพื่อแสดง progress bar
for audio_path in tqdm(wav_files, desc="Transcribing audio files"):
    try:
        # โหลดไฟล์เสียงจาก 'เพลย์ลิสต์' ของเรา
        audio, sr = librosa.load(audio_path, sr=16000)

        # ประมวลผลและถอดเสียง (เหมือนเดิม)
        input_features = processor(audio, sampling_rate=sr, return_tensors="pt").input_features
        predicted_ids = model.generate(input_features)
        transcription = processor.batch_decode(predicted_ids, skip_special_tokens=True)[0]

        # เก็บชื่อไฟล์และผลลัพธ์
        file_name = os.path.basename(audio_path)
        results.append({"file": file_name, "caption": transcription})

    except Exception as e:
        # กรณีที่ไฟล์เสียงบางไฟล์อาจมีปัญหา
        file_name = os.path.basename(audio_path)
        results.append({"file": file_name, "caption": f"ERROR: {e}"})

# --- 4. Print All Results (ส่วนอัปเกรด) ---
print("\n--- Transcription Complete! ---\n")
for result in results:
    print(f"File: {result['file']} -> Caption: {result['caption']}\n")

# --- 5. บันทึกผลลัพธ์ลงม้วนคัมภีร์! (ส่วนที่เพิ่มใหม่) ---
output_filename = "emotion_results.json"
with open(output_filename, 'w', encoding='utf-8') as f:
    json.dump(results, f, ensure_ascii=False, indent=4)

print(f"✅ Results successfully saved to '{output_filename}'")
# Out:
# Loading Whisper model...
# preprocessor_config.json: 0.00B [00:00, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# normalizer.json: 0.00B [00:00, ?B/s]
# added_tokens.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.99G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/1.18G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json: 0.00B [00:00, ?B/s]
# Model loaded successfully!
# Found 300 audio files to process in '../final_audio_output_final/'
# Transcribing audio files:   0%|          | 0/300 [00:00<?, ?it/s]The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Transcribing audio files: 100%|██████████| 300/300 [2:21:31<00:00, 28.31s/it]
# --- Transcription Complete! ---
#
# File: dialogue_16_utterance_1.wav -> Caption: laion – caption, A male speaker expresses anxiety about not being able to see his brothers. His tone is somewhat worried and hesitant. The recording quality is clear, with no noticeable background noise. The speaker's voice is soft and slightly anxious, conveying a sense of vulnerability.
#
# File: dialogue_9_utterance_9.wav -> Caption: laion  caption. A male speaker, with a somewhat hesitant and slightly sarcastic tone, expresses that it would be too risky to put himself out there just to get hurt again. The recording quality is clear, with no noticeable background noise. His voice has a slightly mocking quality.
#
# File: dialogue_14_utterance_7.wav -> Caption: laion ** caption): A male speaker, with a slightly melancholic tone, expresses a feeling of being forgotten. His voice is clear and the recording quality is good. He speaks with a moderate pace, conveying a sense of sadness and isolation. He describes how the world has drifted apart, leaving him helpless.
#
# File: dialogue_3_utterance_11.wav -> Caption: laion.2% The audio features a female speaker, with a slightly anxious and reflective tone, discussing managing her anxiety and avoiding being too hard on herself. Her voice is clear and somewhat hesitant, suggesting a feeling of unease. The recording quality is good, with no noticeable background noise.
#
# File: dialogue_12_utterance_16.wav -> Caption: laion ** captionation): This audio features a male speaker, with a slightly hesitant tone, who is discussing something that feels distant or unrealistic. His voice is clear, but there's a sense of doubt or uncertainty in his delivery. The recording quality is good, with no noticeable background noise.
#
# File: dialogue_12_utterance_11.wav -> Caption: laion  caption. A male speaker, with a casual and slightly dismissive tone, states that most people he talks to don't understand a certain topic. His voice is clear and conversational, with a hint of sarcasm. The recording quality is good, with no noticeable background noise. He sounds like he is in his 30s or 40s.
#
# File: dialogue_16_utterance_6.wav -> Caption: laion  caption – A male speaker, with a slightly anxious tone, describes his thoughts while imagining potential lockdowns. His voice is clear, and the recording quality is good. He sounds worried and concerned.
#
# File: dialogue_7_utterance_10.wav -> Caption: laion ** caption** A male speaker, with a calm and reasonable tone, states that something makes sense and that he hasn't really thought about questioning someone's opinions before. The recording is clear and the speaker's voice is steady.
#
# File: dialogue_10_utterance_2.wav -> Caption: laion. The speaker, a male with a slightly melancholic tone, expresses feelings of isolation and loneliness due to his interest in crystals. He speaks with a somewhat hesitant manner, admitting that people often perceive him differently. The recording quality is clear, with no noticeable background noise.
#
# File: dialogue_12_utterance_4.wav -> Caption: laion ** speech, with a calm and slightly conversational tone. The speaker is describing a recurring habit, speaking with a measured pace. The recording quality is clear, with no noticeable background noise. The speaker sounds relaxed and somewhat reflective.
#
# File: dialogue_16_utterance_8.wav -> Caption: laion ** caption&’ The audio features a male speaker with a thoughtful and slightly hesitant tone. He expresses uncertainty, stating, “I’m not sure.” He then adds, with a more reflective tone, that it feels real, despite uncertainty. The recording quality is clear, with no noticeable background noise.
#
# File: dialogue_9_utterance_7.wav -> Caption: laion – caption. The audio features a male speaker with a somewhat melancholic and reflective tone. He expresses feelings of being judged and not being accepted for who he is. His voice is clear, but there's a hint of sadness and resignation. The recording quality is good, with no noticeable background noise. He speaks at a moderate pace.
#
# File: dialogue_14_utterance_9.wav -> Caption: laion.laion.ta. The speaker, a male, sounds somewhat resigned and perhaps a little weary. He states, with a touch of resignation, that he doesn't want to burden others with his anxieties. The recording quality is clear, with no noticeable background noise.
#
# File: dialogue_10_utterance_5.wav -> Caption: laion. The speaker, a male, expresses a mix of frustration and self-awareness. His tone is somewhat strained, as if he's struggling to maintain composure. He acknowledges his tendency to ignore others' emotions while acknowledging his own passion, but also expresses a difficulty in avoiding feeling hurt. The recording quality is clear, with no noticeable background noise.
#
# File: dialogue_12_utterance_3.wav -> Caption: laion **The audio contains only silence, with no discernible sound events detected.]
#
# File: dialogue_16_utterance_10.wav -> Caption: laion1:]:] focus on the speaker's voice, which is calm and measured. The recording is clear, with no noticeable background noise. The speaker's tone is reassuring and slightly upbeat.
#
# File: dialogue_13_utterance_11.wav -> Caption: laion-style conversation, with a male speaker, who sounds middle-aged, speaking in a calm and conversational tone. He discusses a relationship's history of connection, even during challenging times. The recording is clear, with a slight room tone.
#
# File: dialogue_7_utterance_9.wav -> Caption: laion – caption – A male speaker, with a calm and thoughtful tone, discusses the truth of what people say. His voice is clear and measured, suggesting a reflective mood. The recording quality is good, with no noticeable background noise. He acknowledges that not everything is true, but emphasizes the importance of remembering that information in the moment.
#
# File: dialogue_18_utterance_1.wav -> Caption: laion ** caption** A male speaker expresses concern and worry about his brothers, mentioning his fear of losing touch with them. His tone is gentle and slightly anxious. The recording quality is clear, with no noticeable background noise.
#
# File: dialogue_1_utterance_3.wav -> Caption: laion. The speaker, a female, sounds distressed and anxious. Her voice is shaky and filled with worry. She speaks with a slow, deliberate pace, conveying a sense of deep concern. The recording quality is clear, capturing the emotional nuances of her voice.
#
# File: dialogue_3_utterance_5.wav -> Caption: laion. The speaker, a female, speaks with a calm and neutral tone, stating that she has a few close friends. The recording is clear and focused on her voice.
#
# File: dialogue_1_utterance_4.wav -> Caption: laion ** caption** A female speaker, with a slightly emotional tone, expresses a feeling of having done something differently. She mentions letting animals down and wanting to be remembered. The recording quality is clear, with a slight room tone.
#
# File: dialogue_3_utterance_2.wav -> Caption: laion. The recording is clear and there are no background noises.
#
# File: dialogue_18_utterance_6.wav -> Caption: laion ** caption! A male speaker, with a casual and slightly hesitant tone, responds to a question by stating, “not really.” He then describes his attempts to distract himself with hobbies, noting that these thoughts keep coming back stronger. The recording is clear, with a natural room tone.
#
# File: dialogue_5_utterance_8.wav -> Caption: laion ** caption** A male speaker, with a tone of happiness and excitement, describes finding a rare crystal and feeling like he had discovered something special. The recording is clear, with no noticeable background noise.
#
# File: dialogue_2_utterance_11.wav -> Caption: laion
#
# File: dialogue_17_utterance_10.wav -> Caption: laion
#
# File: dialogue_18_utterance_8.wav -> Caption: laion  caption. The audio features a male speaker with a slightly hesitant and reflective tone. He describes feeling better for a while, but then the fear creeps back in, stating that the calls won't replace seeing them in person. The recording quality is clear, with no noticeable background noise.
#
# File: dialogue_20_utterance_15.wav -> Caption: laion – caption – A female speaker, with a calm and somewhat relieved tone, expresses feeling less alone with her worries. Her voice is clear and pleasant, and the recording quality is good. She sounds very peaceful.
#
# File: dialogue_5_utterance_6.wav -> Caption: laion – caption, with a male speaker, who sounds middle-aged, expressing a mix of comfort and frustration. He speaks in a thoughtful and slightly hesitant manner, with a somewhat subdued tone. The recording quality is clear, with no noticeable background noise. He is discussing negative remarks and their impact on him.
#
# File: dialogue_7_utterance_7.wav -> Caption: laion – caption – A male speaker with a calm and slightly hesitant tone is heard. He is discussing his tendency to brush off positive comments. The recording quality is clear, with no noticeable background noise.
#
# File: dialogue_20_utterance_12.wav -> Caption: laion. The audio features a male speaker with a warm and conversational tone. He is discussing video calls and family chats, expressing a sense of connection. The recording quality is good, with a clear and natural sound.
#
# File: dialogue_5_utterance_1.wav -> Caption: laion.com presents a male speaker with a slightly melancholic tone, stating, “Hi, I’ve been feeling pretty isolated and lonely. It’s been tough.” The recording quality is clear, and the speaker's voice is well-captured. The delivery is somewhat subdued and reflective, suggesting a sense of vulnerability and emotional strain.
#
# File: dialogue_6_utterance_10.wav -> Caption: laion ** caption): A male speaker with a calm and reflective tone discusses focusing on crystals and their energies. He acknowledges that it helps a bit but is hard to ignore the negativity. The recording is clear, with no noticeable background noise. His voice is relaxed and thoughtful.
#
# File: dialogue_15_utterance_9.wav -> Caption: laion  caption. The audio features a male speaker, who sounds somewhat casual and conversational. He discusses the impact of the pandemic on travel, acknowledging its past positive impact, but then noting the lack of permanent restrictions. He also mentions using video calls as a way to stay in touch. The recording quality is clear, with no noticeable background noise.
#
# File: dialogue_8_utterance_7.wav -> Caption: laion **The audio features a male speaker with a calm and reflective tone, discussing the fleeting nature of certain things. His voice is clear and measured, suggesting a thoughtful mood. The recording quality is good, with no noticeable background noise. He sounds like he is in a state of contemplation.
#
# File: dialogue_13_utterance_3.wav -> Caption: laion The audio features a male speaker with a slightly worried tone, discussing past interactions and travel restrictions. He speaks at a moderate pace, and the recording quality is clear. He expresses concern about their ability to see each other as much.
#
# File: dialogue_5_utterance_10.wav -> Caption: laion – caption – A male speaker, with a reflective and slightly optimistic tone, discusses remembering a sense of discovery and something that makes him happy. His voice is clear and the recording quality is good. He sounds thoughtful and positive.
#
# File: dialogue_11_utterance_5.wav -> Caption: laion ** with a slightly nervous and self-deprecating tone, talks about feeling like a weirdo. The recording is clear, with a conversational feel. There is a sense of vulnerability and humor in the delivery.
#
# File: dialogue_14_utterance_10.wav -> Caption: laion
#
# File: dialogue_13_utterance_4.wav -> Caption: laion – caption. The speaker, a male, expresses feelings of anxiety and fear, using a slow and deliberate tone. He describes feelings of drifting apart or losing touch. The recording quality is clear, with no noticeable background noise.
#
# File: dialogue_11_utterance_2.wav -> Caption: laion. The recording features a male speaker with a somewhat melancholic and introspective tone. He expresses feelings of isolation and loneliness, mentioning his interest in crystals. He also acknowledges that people perceive him differently, which makes him feel down. The recording quality is clear, with no noticeable background noise.
#
# File: dialogue_17_utterance_8.wav -> Caption: laion  caption caption. A male speaker, with a casual and slightly humorous tone, discusses technology's effect. His voice is clear and conversational, with a hint of amusement. The recording quality is good, with no noticeable background noise. He speaks with a relaxed and easygoing manner.
#
# File: dialogue_8_utterance_13.wav -> Caption: laion  caption. The audio features a female speaker with a conversational tone, discussing a colleague at work who seems open to meditation and holistic health. Her voice is clear and friendly, with a hint of amusement. The recording quality is good, with no noticeable background noise. She sounds relaxed and casual.
#
# File: dialogue_10_utterance_16.wav -> Caption: laion ** chuckles ** and then speaks with a positive and determined tone, expressing his readiness to work on changing his feelings about his interests. The recording is clear, with a slight room tone.
#
# File: dialogue_1_utterance_11.wav -> Caption: laion ** caption): A female voice, with a slightly skeptical tone, expresses doubt about a plan. Her voice is clear and somewhat hesitant, and she speaks at a moderate pace. The recording quality is good, with no noticeable background noise. She sounds doubtful and unsure.
#
# File: dialogue_19_utterance_14.wav -> Caption: laion ** sincerity, with a tone of hopefulness, speaks about having a plan. The recording is clear, with a focus on the speaker's voice. The speaker sounds calm and collected.
#
# File: dialogue_17_utterance_6.wav -> Caption: laion  caption – A male speaker, with a somewhat reflective tone, expresses concern about not being able to see people for years. He also mentions it could be worse. The recording is clear, with no noticeable background noise.
#
# File: dialogue_15_utterance_7.wav -> Caption: laion  caption relates a story about a person who became a hero. The speaker's tone is informative and slightly dramatic, suggesting a narrative or storytelling context. The recording quality is clear, with no noticeable background noise.
#
# File: dialogue_8_utterance_9.wav -> Caption: laion ** caption** A male speaker with a calm and reflective tone expresses appreciation for the sense of peace and clarity some things give him, comparing it to a personal sanctuary. His voice is gentle and soothing, suggesting a sense of contentment and serenity. The recording quality is clear, with no noticeable background noise.
#
# File: dialogue_17_utterance_1.wav -> Caption: laion.com is heard, with a female voice that sounds somewhat anxious and hesitant. She speaks with a slightly nervous tone, and the recording quality is clear. The speaker seems to be expressing her feelings with a hint of uncertainty.
#
# File: dialogue_8_utterance_14.wav -> Caption: laion ** caption** A female speaker, with a slightly nervous but optimistic tone, expresses her desire to try something. Her voice is clear and the recording quality is good. She speaks with a moderate pace, and her tone is both hesitant and hopeful.
#
# File: dialogue_10_utterance_11.wav -> Caption: laion  caption. A male speaker, with a slightly frustrated tone, expresses feeling unfairly labeled. He acknowledges that everyone has their own interests, but questions why his interests have to be seen as weird. The recording is clear, with no noticeable background noise.
#
# File: dialogue_19_utterance_13.wav -> Caption: laion ** caption** A male speaker, with a calm and thoughtful tone, is heard in this recording. His voice is clear and steady, and he speaks with a moderate pace. The recording quality is good, with no noticeable background noise. He sounds like he is offering a suggestion or a comment in a conversational manner.
#
# File: dialogue_20_utterance_5.wav -> Caption: laion.com, a male speaker with a slightly frustrated tone, expresses concern about the lack of understanding from others. His voice is clear and the recording quality is good. He sounds a bit weary and disappointed.
#
# File: dialogue_4_utterance_1.wav -> Caption: laion  caption – A male speaker, with a somewhat downcast and subdued tone, states that he is okay but feeling down lately. The recording is clear, with no noticeable background noise. The speaker's voice is soft and a little weary.
#
# File: dialogue_15_utterance_10.wav -> Caption: laion  “ The male speaker has a calm and reassuring tone. He speaks about staying in touch through video calls and the possibility of drifting apart. His voice is clear and steady, and the recording quality is good. He sounds thoughtful and somewhat optimistic.
#
# File: dialogue_6_utterance_7.wav -> Caption: laion  describes sometimes with close friends and senses a bit of judgement. He mentions that his interest in crystals determines how they see him. The speaker's tone is thoughtful and slightly introspective. The recording quality is clear, with no noticeable background noise.
#
# File: dialogue_20_utterance_2.wav -> Caption: laion A male speaker with a calm and reflective tone discusses the impact of news on his worries about the pandemic and travel restrictions. He mentions that trying to distract from hobbies can be a long-term solution. The recording is clear, with no noticeable background noise.
#
# File: dialogue_4_utterance_10.wav -> Caption: laion A male speaker, with a calm and conversational tone, confirms that a few people have shown genuine interest and even asked questions about his crystals. The recording is clear and the speaker's voice is relaxed.
#
# File: dialogue_4_utterance_6.wav -> Caption: laion  caption. The audio features a male speaker with a slightly hesitant and somewhat strained tone. He is discussing his relationships and interests. The recording quality is clear, with no noticeable background noise. His speech is deliberate and thoughtful.
#
# File: dialogue_19_utterance_8.wav -> Caption: laion  caption – A male speaker with a calm and somewhat hesitant tone is heard. He is discussing his tendency to isolate himself and avoid video calls and messages. His voice is clear, and the recording quality is good. He sounds like he is sharing a personal observation.
#
# File: dialogue_2_utterance_2.wav -> Caption: laion.com file containing a female speaker with a soft, somewhat guilty tone. Her voice is clear, and the recording quality is good. She speaks with a hesitant pace, conveying a sense of unease. She describes a feeling of guilt and a desire to avoid a situation.
#
# File: dialogue_18_utterance_13.wav -> Caption: laion  caption, The speaker, a male, expresses a sense of anxiety, using a slightly hesitant tone. He mentions being made to think of worst-case scenarios, which makes it difficult to focus on the good parts. The recording is clear, with no noticeable background noise.
#
# File: dialogue_4_utterance_8.wav -> Caption: laion ** captioned” The audio features a male speaker, with a slightly hesitant tone, expressing a concern about being perceived as weird or not normal based on his interests. The recording quality is clear, with no noticeable background noise.
#
# File: dialogue_19_utterance_6.wav -> Caption: laion  caption – A male speaker, with a slightly melancholic tone, expresses a fear of not seeing someone again, describing it as a voice in his head. The recording is clear, with no noticeable background noise.
#
# File: dialogue_11_utterance_11.wav -> Caption: laion ** caption** A male speaker, with a casual and slightly hesitant tone, expresses a desire to try something, saying, “I think I could give it a try. It might help to balance things out a bit.” The recording quality is clear, with no noticeable background noise. His voice is calm and measured, suggesting a thoughtful approach.
#
# File: dialogue_9_utterance_14.wav -> Caption: laion – caption – A male speaker, with a calm and optimistic tone, expresses his belief that things can get better, even if it's hard. The recording is clear, with no noticeable background noise. The speaker's voice is steady and reassuring.
#
# File: dialogue_18_utterance_14.wav -> Caption: laion1's story. The speaker, a male, sounds thoughtful and somewhat hesitant. He's discussing negative thoughts and how they feel real and strong. The recording quality is clear, with no noticeable background noise. He seems to be reflecting on a topic.
#
# File: dialogue_19_utterance_1.wav -> Caption: laion  caption! A male speaker expresses anxiety and stress, with a slightly breathy voice, about not seeing his brothers again. The recording quality is clear, and the speaker sounds genuinely overwhelmed.
#
# File: dialogue_6_utterance_9.wav -> Caption: laion  caption. A male speaker, with a somewhat melancholic tone, expresses feelings of sadness and loneliness. His voice is clear, but there's a sense of quiet despair. He speaks about feeling down when criticized. The recording quality is good, with no noticeable background noise.
#
# File: dialogue_9_utterance_13.wav -> Caption: laion ** caption** A male speaker with a confident and slightly upbeat tone expresses a sense of self-assurance. His voice is clear and articulate, suggesting a well-practiced delivery. The recording quality is good, with no noticeable background noise. He speaks with a sense of determination.
#
# File: dialogue_2_utterance_5.wav -> Caption: laion – caption. A female speaker with a calm and reflective tone describes how memories sometimes just pop into her head, particularly when reminded of the shelter or seeing something on social media. Her voice is clear and the recording quality is good.
#
# File: dialogue_7_utterance_6.wav -> Caption: laion
#
# File: dialogue_20_utterance_13.wav -> Caption: laion – caption. The speaker, a male, expresses a feeling of relief and a hint of hope, stating that something might make him feel less alone. His voice is calm and measured, with a slight breathiness. The recording quality is clear, with no noticeable background noise.
#
# File: dialogue_6_utterance_11.wav -> Caption: laion ** narrative style, with a slightly worried tone. The speaker expresses concern about being perceived as overly sensitive or dramatic. The voice is clear and the recording quality is good, with no noticeable background noise.
#
# File: dialogue_17_utterance_11.wav -> Caption: laion  caption. A male speaker, with a calm and somewhat thoughtful tone, expresses that something sounds doable. He then mentions having some structure to help reduce anxiety. The recording is clear, with no noticeable background noise.
#
# File: dialogue_7_utterance_1.wav -> Caption: laion ** caption& A male speaker, with a calm and somewhat melancholic tone, expresses feelings of isolation and loneliness. His voice is clear and steady, but with a hint of sadness. The recording quality is good, with no noticeable background noise. He mentions that people make comments about his interest in crystals, which is causing him emotional pain.
#
# File: dialogue_18_utterance_9.wav -> Caption: laion  caption – A male speaker, with a somewhat hesitant and thoughtful tone, expresses a feeling of unease, stating there isn't concrete evidence but a nagging feeling that things will go bad. His voice is clear, and the recording quality is good, with no noticeable background noise. He speaks with a moderate pace, and his tone suggests a degree of concern and apprehension.
#
# File: dialogue_20_utterance_14.wav -> Caption: laion  caption. The audio features a male speaker, sounding hopeful and determined, discussing the potential benefits of writing things down. His voice is clear and optimistic, suggesting a positive mindset. The recording quality is good, with no noticeable background noise. He sounds like he is trying something new and is eager to proceed.
#
# File: dialogue_5_utterance_7.wav -> Caption: laion >>[ portrays prominent rock and roll music with a driving drum beat and electric guitar sounds. The recording quality is clear and well-produced, suggesting a studio environment.
#
# File: dialogue_1_utterance_5.wav -> Caption: laion.ta, with a melancholic and somewhat defeated tone, suggesting a personal failure. The speaker, likely an adult, expresses a sense of resignation and perhaps a hint of sadness. The recording quality is clear, with no noticeable background noise.
#
# File: dialogue_3_utterance_3.wav -> Caption: laion  caption. The female speaker sounds weary and a bit sad, expressing her inability to sleep well and feeling disconnected from her passion. Her voice is soft and a bit melancholic. The recording quality is clear, with no noticeable background noise.
#
# File: dialogue_18_utterance_7.wav -> Caption: laion ** caption): A male speaker with a reflective tone discusses past experiences, mentioning a video call that went well but noting that those moments are rare. He uses the metaphor of a band-aid that doesn't last. The recording quality is clear, with a slight room tone.
#
# File: dialogue_5_utterance_9.wav -> Caption: laion ** excited and proud, with a slightly breathy quality to his voice. He speaks with a moderate pace, conveying a sense of enthusiasm and satisfaction. The recording quality is clear, with no noticeable background noise.
#
# File: dialogue_2_utterance_10.wav -> Caption: laion.com is the main feature of this audio file. The speaker, a female, has a thoughtful and reflective tone. She discusses how others might be reacting to her, and she expresses a sense of understanding and empathy. Her voice is clear and calm, and the recording quality is good.
#
# File: dialogue_13_utterance_10.wav -> Caption: laion ** caption’s first speaker, a male, speaks with a calm and reflective tone, expressing a sense of possibility and uncertainty. His voice is clear and steady, and the recording quality is good. He seems to be in a state of hope and reflection.
#
# File: dialogue_7_utterance_8.wav -> Caption: laion ** thoughtful **, with a slightly hesitant tone, mentions trying to remind himself of positive things. The recording is clear, with a slight room tone.
#
# File: dialogue_1_utterance_2.wav -> Caption: laion.com presents a female speaker with a reflective and slightly melancholic tone. She recounts a past experience at a shelter, noting how some animals didn't recognize her, expressing a sense of being rejected. Her voice is soft and somewhat subdued, conveying a feeling of sadness and vulnerability. The recording quality is clear, with no noticeable background noise.
#
# File: dialogue_3_utterance_4.wav -> Caption: laion – caption. The female speaker sounds distressed and anxious, her voice wavering slightly. She describes a struggle, stating, “I try to push them away or distract myself, but it doesn't really work. The anxiety just keeps coming back and I can't seem to change my beliefs, no matter what I do.” The recording quality is clear, but the speaker's emotional state is very palpable.
#
# File: dialogue_9_utterance_6.wav -> Caption: laion ** caption): A male speaker with a somewhat reflective tone is heard. His voice is clear and the recording quality is good. He is discussing feelings of isolation and judgment. The speaker sounds thoughtful and slightly troubled.
#
# File: dialogue_14_utterance_8.wav -> Caption: laion  “ No, not really. They've all been supportive and we talk on the phone and video chat, but it feels like it's not enough. I just can't shake the feeling. “
#
# File: dialogue_7_utterance_16.wav -> Caption: laion  caption
#
# File: dialogue_10_utterance_4.wav -> Caption: laion ** caption1 This audio features a male speaker with a calm and clear voice. He is responding to something, and his tone is affirmative. The recording quality is good, with no noticeable background noise. He sounds like he is in his 30s or 40s.
#
# File: dialogue_12_utterance_2.wav -> Caption: laion  caption, A male speaker, with a slightly melancholic tone, expresses a feeling of isolation and loneliness due to his interest in crystals. His voice is clear and the recording quality is good. He speaks with a somewhat reflective and subdued manner.
#
# File: dialogue_16_utterance_11.wav -> Caption: laion  caption. The audio presents a male speaker with a calm and friendly tone. He expresses willingness to manage a situation. The recording quality is clear, with no noticeable background noise.
#
# File: dialogue_7_utterance_11.wav -> Caption: laion The audio features a male speaker with a calm and gentle tone. He is discussing meditation and its effects on his state of mind. The recording quality is clear, with no noticeable background noise. His voice is soothing and reflective.
#
# File: dialogue_10_utterance_3.wav -> Caption: laion  caption. A male speaker with a calm and reflective tone describes his fascination with something. He mentions using it for meditation and decorating his space. The recording quality is clear, with no noticeable background noise. His voice is gentle and thoughtful.
#
# File: dialogue_12_utterance_5.wav -> Caption: laion.laion.subs. A male speaker with a slightly strained voice expresses frustration about negative comments and his passion for crystals. He speaks with a mix of resignation and slight amusement. The recording quality is clear, with no noticeable background noise.
#
# File: dialogue_16_utterance_9.wav -> Caption: laion  caption. The audio features a male speaker, who sounds calm and conversational, discussing staying connected through phone calls and video chats. He mentions that they were unable to meet in person, but there are also some restrictions of ease. The recording quality is clear, with no noticeable background noise.
#
# File: dialogue_9_utterance_1.wav -> Caption: laion – caption – A male speaker, with a somewhat downcast and isolated tone, expresses feelings of loneliness and rejection. His voice is clear but carries a sense of disappointment and vulnerability. The recording quality is good, with no noticeable background noise. The speaker's delivery is slow and hesitant, reflecting his emotional state.
#
# File: dialogue_12_utterance_10.wav -> Caption: laion ** captioned. The audio features a male speaker with a calm and reflective tone. He describes feeling happy and peaceful when he focuses on good things, but he also acknowledges the challenge of remaining in that mindset. His voice is clear and steady, and the recording quality is good. He sounds thoughtful and somewhat introspective.
#
# File: dialogue_16_utterance_7.wav -> Caption: laion The audio features a male speaker, sounding somewhat anxious and concerned, expressing worry about the possibility of not seeing family members due to a lockdown. His voice is clear, and the recording quality is good, with no noticeable background noise. He speaks with a fast pace, conveying a sense of urgency.
#
# File: dialogue_14_utterance_1.wav -> Caption: laion ** caption’ A male speaker, with a slightly casual and somewhat weary tone, expresses that he is okay, though he notes that the situation has been tough lately. His voice is clear and the recording quality is good.
#
# File: dialogue_9_utterance_8.wav -> Caption: laion – caption – A male speaker, with a somewhat melancholic tone, expresses feelings of isolation and a desire to withdraw. His voice is clear but conveys a sense of sadness and resignation. The recording quality is good, with no noticeable background noise. He speaks at a moderate pace, and his delivery is thoughtful and reflective.
#
# File: dialogue_14_utterance_6.wav -> Caption: laion ** caption’s voice, conveying a mix of sadness and fear, as he describes a recurring thought about what might happen if he never saw his brothers again. His voice is slightly breathy, and the recording quality is clear, with no noticeable background noise.
#
# File: dialogue_3_utterance_10.wav -> Caption: laion
#
# File: dialogue_12_utterance_17.wav -> Caption: laion  caption, with a hesitant and somewhat uncertain tone. The speaker is expressing doubt about something's impact, stating it's hard to believe. The recording quality is clear, with no noticeable background noise.
#
# File: dialogue_18_utterance_15.wav -> Caption: laion. The audio features a male speaker with a somewhat resigned tone, expressing uncertainty about a situation. His voice is clear, and the recording quality is good. He speaks at a moderate pace, conveying a sense of doubt. The speaker's tone is hesitant, suggesting a lack of confidence.
#
# File: dialogue_6_utterance_8.wav -> Caption: laion
#
# File: dialogue_9_utterance_12.wav -> Caption: laion ** caption): A male speaker with a thoughtful and reflective tone discusses the importance of analyzing positive comments and interactions, even in small settings, to understand them. His voice is calm and measured, suggesting a thoughtful approach. The recording quality is clear, with no noticeable background noise.
#
# File: dialogue_2_utterance_4.wav -> Caption: laion  caption. The female speaker has a calm and somewhat melancholic tone, expressing feelings of distress and worry. She mentions avoiding a shelter and the strain it causes her relationships with volunteers. Her voice is clear, but there's a noticeable sadness in her tone. The recording quality is good, with no noticeable background noise. She also mentions her sleep being a mess, indicating a state of distress.
#
# File: dialogue_2_utterance_3.wav -> Caption: laion.com, with a clear and neutral tone. The recording is of good quality, with no noticeable background noise. The speaker is talking about something that started a few months ago.
#
# File: dialogue_18_utterance_12.wav -> Caption: laion. caption. A male speaker, with a calm and slightly sarcastic tone, is heard. He speaks with a measured pace, and his voice has a slightly dry quality. The recording quality is clear, with no noticeable background noise. He seems to be expressing a skeptical opinion.
#
# File: dialogue_4_utterance_9.wav -> Caption: laion
#
# File: dialogue_19_utterance_7.wav -> Caption: laion ** speaks with a distressed and somewhat panicked tone, describing feelings of sadness and focus loss. The voice is clear, and the recording quality is good. The speaker sounds anxious and distressed.
#
# File: dialogue_11_utterance_10.wav -> Caption: laion ** caption’s a male speaker laughs heartily, then states that positive reactions are just as valid as negative ones. The speaker's tone is lighthearted and humorous. The recording quality is clear, with no noticeable background noise.
#
# File: dialogue_9_utterance_15.wav -> Caption: laion **cognizant** is the word I use to thank someone and then offers to try again. The tone is friendly and polite. The recording is clear and focused on the speaker's voice.
#
# File: dialogue_20_utterance_3.wav -> Caption: laion  caption. The audio features a male speaker with a calm and reflective tone. He is discussing a future where people are just strangers, and the recording quality is clear. He expresses anxiety about the future.
#
# File: dialogue_4_utterance_7.wav -> Caption: laion � caption’ A male speaker, with a calm and somewhat hesitant tone, begins by stating he has friends. He then mentions he is comfortable discussing general things, but does not like to deal with his feelings of isolation. The recording quality is clear, with no noticeable background noise.
#
# File: dialogue_4_utterance_11.wav -> Caption: laion  caption. A male speaker with a somewhat hesitant tone says
#
# File: dialogue_19_utterance_9.wav -> Caption: laion The audio presents a male speaker with a calm and conversational tone. He discusses positive experiences, using a clear and measured delivery. The recording quality is good, with no noticeable background noise.
#
# File: dialogue_6_utterance_1.wav -> Caption: laion – caption – A male speaker, with a slightly downcast and melancholic tone, expresses feelings of isolation and loneliness. His voice is soft and somewhat hesitant, conveying a sense of vulnerability. The recording quality is clear, with no noticeable background noise.
#
# File: dialogue_20_utterance_4.wav -> Caption: laion  caption. The male speaker, with a thoughtful and slightly hesitant tone, discusses avoiding talking to people, sometimes due to fear or reaching out more than usual. He expresses a desire not to overwhelm them, but his tone suggests a degree of concern. The recording is clear, with no noticeable background noise.
#
# File: dialogue_6_utterance_6.wav -> Caption: laion  caption – A male speaker with a slightly hesitant tone describes a feeling of walking on eggshells and avoiding conversations about personal concerns. The recording is clear, with a slight room tone. The speaker's voice is somewhat soft and introspective.
#
# File: dialogue_15_utterance_11.wav -> Caption: laion  caption – A male speaker, with a thoughtful and slightly hesitant tone, expresses difficulty finding positive outcomes when focused on the worst-case scenario. His voice is clear and the recording quality is good.
#
# File: dialogue_15_utterance_6.wav -> Caption: laion ** caption): The audio features a male speaker with a casual and slightly humorous tone. He describes his attempts to distract himself, but nothing seems to work. A loud, short, and high-pitched vocal burst, a kind of scream or shout, is heard immediately after the speech. The recording quality is clear, with no noticeable background noise.
#
# File: dialogue_8_utterance_8.wav -> Caption: laion  caption. The speaker, a male, sounds somewhat anxious and self-conscious. He speaks with a hesitant pace, expressing a feeling of being judged by others. The recording quality is clear, with no noticeable background noise. He seems to be in a state of worry.
#
# File: dialogue_8_utterance_15.wav -> Caption: laion  caption? There's a sense of confidence and determination in his voice. He states,
#
# File: dialogue_10_utterance_10.wav -> Caption: laion  The speaker, a male with a slightly nasal voice, expresses a sense of frustration and regret. He describes focusing on crystals while expressing a desire to ignore negative comments. His tone is somewhat melancholic, and the recording quality is clear, suggesting a studio or quiet environment.
#
# File: dialogue_19_utterance_12.wav -> Caption: laion ** chuckling ** and then says, “I think that's a good idea. I'll aim to send each of them a message or make a quick call this week.” The recording is clear, with a conversational tone. The speaker sounds calm and collected.
#
# File: dialogue_8_utterance_12.wav -> Caption: laion ** caption** A male speaker, with a slightly hesitant tone, expresses a willingness to take a risk. His voice is clear and the recording quality is good. He sounds like he is considering a possibility.
#
# File: dialogue_1_utterance_10.wav -> Caption: laion – caption): A female speaker, with a thoughtful and slightly hesitant tone, discusses the need for something concrete to counter some thoughts. Her voice is clear and articulate, but she sounds uncertain about how to proceed. The recording quality is good, with no noticeable background noise.
#
# File: dialogue_15_utterance_1.wav -> Caption: laion  caption! A male speaker expresses anxiety and worry about not being able to see his brothers, despite having eight of them during the pandemic. His tone is concerned and slightly distressed. The recording quality is clear, with no noticeable background noise.
#
# File: dialogue_17_utterance_7.wav -> Caption: laion ** caption** A male speaker, with a slightly concerned tone, discusses the impact of the pandemic and travel restrictions. His voice is clear and the recording quality is good. He expresses a sense of worry about getting back to normal.
#
# File: dialogue_14_utterance_11.wav -> Caption: laion ** caption’s The audio presents a male speaker with a calm and thoughtful tone. He expresses a desire to change his feelings. The recording quality is clear, with no noticeable background noise.
#
# File: dialogue_13_utterance_5.wav -> Caption: laion  caption includes a male speaker with a conversational tone, discussing news about the pandemic and travel restrictions. His voice is clear and the recording quality is good. He expresses a sense of frustration, but also a sense of resignation.
#
# File: dialogue_5_utterance_16.wav -> Caption: laion
#
# File: dialogue_11_utterance_3.wav -> Caption: laion ** caption): A male speaker expresses frustration and resentment. His voice is clear but carries a tone of bitterness. He describes feeling like an outcast when people mock his interests. The recording quality is good, with no noticeable background noise. He sounds somewhat defeated and annoyed.
#
# File: dialogue_8_utterance_1.wav -> Caption: laion ** caption** A male speaker, with a slightly melancholic and isolated tone, explains his feeling of loneliness. His voice is clear and calm, but with a hint of sadness. The recording quality is good, with no noticeable background noise.
#
# File: dialogue_17_utterance_9.wav -> Caption: laion  caption. The speaker, a male, expresses a preference for video calls. His tone is calm and reassuring. The recording quality is clear, with no noticeable background noise. He speaks with a moderate pace and a relaxed style.
#
# File: dialogue_15_utterance_8.wav -> Caption: laion con chat. The audio features a male speaker, sounding somewhat young, expressing a sense of resignation and concern about travel restrictions. His tone is conversational, with a hint of anxiety. The recording quality is clear, with no noticeable background noise.
#
# File: dialogue_8_utterance_6.wav -> Caption: laion ** caption): A male speaker, with a slightly sarcastic tone, mentions that most people don't get something, so he stopped trying to share. The recording is clear, with a slight room tone.
#
# File: dialogue_13_utterance_2.wav -> Caption: laion  caption. The audio features a male speaker, who sounds conversational and relaxed, discussing his family and the challenges of seeing each other due to the pandemic. His tone is a mix of humor and sadness. The recording quality is clear, with no noticeable background noise.
#
# File: dialogue_5_utterance_11.wav -> Caption: laion.com, where a male speaker with a slightly nasal voice expresses a desire to find communities or groups of people who share his interest in crystals. He sounds somewhat hesitant and then says,
#
# File: dialogue_11_utterance_4.wav -> Caption: laion. The audio features a female speaker with a calm and slightly hesitant tone. She is describing her feelings about people's perceptions of her. The recording quality is clear, with no noticeable background noise. Her voice is soft and thoughtful.
#
# File: dialogue_18_utterance_11.wav -> Caption: laion C. has a conversational tone, expressing a mix of concern and resignation. The speaker, seemingly an adult, acknowledges a situation as inadequate, yet also expresses worry that it isn't enough. The recording quality is clear, suggesting a studio or quiet environment.
#
# File: dialogue_11_utterance_13.wav -> Caption: laion ** caption): A male speaker with a calm and thoughtful tone is heard. He states that he thinks he covered everything on his mind and is curious to see how an experiment will go. The recording quality is clear, with no noticeable background noise.
#
# File: dialogue_19_utterance_4.wav -> Caption: laion A male speaker, with a slightly strained voice, expresses concern about the risks of constant news and travel restrictions. His tone is serious and somewhat worried, indicating a need for caution. The recording is clear, with no noticeable background noise. He speaks with a measured pace, emphasizing the importance of his message.
#
# File: dialogue_18_utterance_16.wav -> Caption: laion caption caption includes a vocal burst, a quick, sharp utterance followed by a brief silence. The speaker sounds somewhat frustrated, expressing a sense of difficulty. The recording quality is clear, with no noticeable background noise.
#
# File: dialogue_20_utterance_9.wav -> Caption: laion  caption – A male speaker, with a thoughtful and slightly hesitant tone, discusses making plans and the uncertainty it feels. His voice is clear and the recording quality is good. He expresses a sense of wonder and uncertainty, but also a sense of acceptance.
#
# File: dialogue_11_utterance_14.wav -> Caption: laion ** caption’ A male speaker, with a warm and appreciative tone, expresses gratitude for the listener. His voice is clear and friendly, and he speaks at a moderate pace. The recording quality is good, with no noticeable background noise. He sounds very thankful and happy.
#
# File: dialogue_19_utterance_3.wav -> Caption: laion The audio features a male speaker with a clear and somewhat concerned tone. He's describing how his mind goes into a spiral when he hears news about the pandemic or travel restrictions. The recording quality is good, with no noticeable background noise.
#
# File: dialogue_9_utterance_11.wav -> Caption: laion ** caption): A male speaker, with a reflective tone, is talking about interactions. He mentions that not every interaction was that bad, and that it's hard to focus on the good ones when the negative ones stick out. The recording is clear, with no noticeable background noise.
#
# File: dialogue_2_utterance_7.wav -> Caption: laion  caption. The female speaker expresses a mix of worry and vulnerability, her voice tinged with a hint of anxiety. She speaks with a slow, thoughtful pace, conveying a sense of internal conflict. The recording is clear, with no noticeable background noise.
#
# File: dialogue_20_utterance_7.wav -> Caption: laion ** caption** A male speaker, with a calm and thoughtful tone, agrees with a previous statement and expresses a need for help managing thoughts. His voice is clear and the recording quality is good. He sounds a bit concerned and is speaking in a conversational manner.
#
# File: dialogue_4_utterance_15.wav -> Caption: laion ** speaks with a calm and reflective tone, discussing the importance of remembering things that help her feel balanced. Her voice is clear and steady, suggesting a thoughtful and introspective mood. The recording quality is good, with no noticeable background noise.
#
# File: dialogue_4_utterance_3.wav -> Caption: laion  The male speaker has a calm and reflective tone, discussing his experience with crystals. He speaks at a moderate pace, with a clear and articulate voice. The recording quality is good, with no noticeable background noise. He mentions getting negative comments which made him feel worse.
#
# ...
#
# File: dialogue_4_utterance_14.wav -> Caption: laion ** caption** A male speaker with a calm and reflective tone describes feeling at peace and connected to something positive, comparing it to a sanctuary. His voice is gentle and soothing, and the recording quality is clear.
#
# File: dialogue_6_utterance_4.wav -> Caption: laion  caption): A male speaker with a calm and reflective tone is heard. He is speaking about a past experience, and his voice is clear and steady. The recording quality is good, with no noticeable background noise. He is speaking in a very calm and relaxed manner.
#
# File: dialogue_15_utterance_13.wav -> Caption: laion ** caption** A male speaker, with a calm and thoughtful tone, discusses setting up a video call schedule and writing letters. The recording is clear, with a slight room tone. The speaker sounds like he is making a suggestion.
#
# File: dialogue_2_utterance_8.wav -> Caption: laion.cord. A female speaker, with a gentle and reflective tone, shares a personal experience. Her voice is soft and slightly hesitant, suggesting a sense of vulnerability. The recording quality is clear, with no noticeable background noise. She describes a newfound sense of connection.
#
# File: dialogue_20_utterance_8.wav -> Caption: laion  caption. The speaker, a male, sounds somewhat resigned and reflective, speaking in a conversational tone. He discusses the impact of the pandemic on their relationship. The recording quality is good, with a clear and natural sound.
#
# File: dialogue_19_utterance_2.wav -> Caption: laion  caption. The audio features a male speaker with a slightly strained and emotional tone. He speaks about the start of the pandemic and travel restrictions. He also mentions not being able to visit his brothers. The recording quality is clear, with no noticeable background noise.
#
# File: dialogue_9_utterance_10.wav -> Caption: laion – caption – A male speaker, with a somewhat sarcastic tone, expresses a sense of self-awareness and frustration. His voice is clear and slightly mocking, suggesting a sense of being underestimated. The recording quality is good, with no noticeable background noise. He speaks with a moderate pace, conveying a sense of resignation and annoyance.
#
# File: dialogue_2_utterance_6.wav -> Caption: laion ** caption** A female voice, with a slightly hesitant tone, expresses a mix of amusement and mild frustration. Her speech is clear and conversational, suggesting a casual setting. The recording quality is good, with no noticeable background noise. She speaks with a slightly self-deprecating tone, acknowledging her overreaction.
#
# File: dialogue_2_utterance_1.wav -> Caption: laion. The audio features a female speaker with a slightly anxious tone, revealing her fear of returning to the animal shelter. Her voice is clear, but there's a hint of distress. The recording quality is good, with no noticeable background noise.
#
# File: dialogue_18_utterance_10.wav -> Caption: laion ** caption** A male speaker with a casual and slightly hesitant tone is heard. He mentions messaging regularly, then expresses that it doesn't feel the same as being there in person. The recording quality is clear, with no noticeable background noise.
#
# File: dialogue_11_utterance_12.wav -> Caption: laion ** caption’ A male speaker with a thoughtful and reflective tone is heard. His voice is calm and measured, suggesting a sense of contemplation. The recording quality is clear, with no noticeable background noise. He is speaking about a change in his perspective, indicating a shift in his thinking.
#
# File: dialogue_19_utterance_5.wav -> Caption: laion. The speaker, a male, expresses a mix of weariness and relief. His voice is slightly breathy, and he speaks with a moderate pace. He describes trying to be occupied but how worries always come back. The recording is clear, with no noticeable background noise.
#
# File: dialogue_3_utterance_15.wav -> Caption: laion
#
# File: dialogue_12_utterance_9.wav -> Caption: laion ** caption): A female speaker with a calm and gentle tone describes the benefits of crystals for meditation and grounding. Her voice is soothing and the recording quality is clear. She speaks with a sense of conviction and belief in her abilities.
#
# File: dialogue_12_utterance_12.wav -> Caption: laion – caption – A male speaker, with a slightly sarcastic tone, is heard making a comment about being perceived as weird. His voice is clear and the recording quality is good. He sounds a bit amused and self-aware.
#
# File: dialogue_16_utterance_5.wav -> Caption: laion ** caption): A male speaker, with a casual and slightly playful tone, states that he's tracked someone down. His voice is clear and relaxed. The recording quality is good, with no noticeable background noise. He sounds like he's having fun.
#
# File: dialogue_14_utterance_3.wav -> Caption: laion The audio features a male speaker with a calm and reflective tone. He's discussing the impact of pandemic restrictions on his anxiety. His voice is clear and steady, and the recording quality is good. He sounds thoughtful and a bit relieved.
#
# File: dialogue_16_utterance_2.wav -> Caption: laion  caption – A male speaker, with a slightly melancholic tone, expresses a personal fear and concern about travel restrictions and missing his brothers. His voice is clear and the recording quality is good. He sounds a bit sad and worried.
#
# File: dialogue_14_utterance_4.wav -> Caption: laion ** caption): This audio features a male speaker with a calm and somewhat resigned tone. He speaks at a moderate pace, and the recording quality is clear. The speaker seems to be discussing a recurring issue or a problem. The tone is slightly weary, but not overly distressed.
#
# File: dialogue_3_utterance_12.wav -> Caption: laion ** caption” A female speaker, with a calm and slightly hesitant tone, mentions trying deep breathing and distracting herself. Her voice is clear and the recording quality is good.
#
# File: dialogue_10_utterance_8.wav -> Caption: laion – caption. A male speaker, with a slightly strained and reflective tone, discusses how things have been strained and how he can no longer be open about his interests. His voice is clear, but with a hint of sadness. The recording quality is good, with no noticeable background noise. He speaks with a slow and deliberate pace.
#
# File: dialogue_12_utterance_15.wav -> Caption: laion ** captiongavel** gut feeling. The speaker, a male, sounds relaxed and content, almost as if he's reflecting on a past event. His tone is calm and assured, with a hint of satisfaction. The recording quality is clear, with no noticeable background noise.
#
# File: dialogue_9_utterance_4.wav -> Caption: laion – caption!  The audio features a male speaker with a slightly nasal voice, speaking in a conversational tone. He expresses mild annoyance or frustration, stating, “I’m fat ball, borra.” The recording quality is clear, suggesting a decent microphone was used.
#
# File: dialogue_7_utterance_14.wav -> Caption: laion ** caption): A female speaker with a calm and thoughtful tone discusses the need to remind herself of the positives. Her voice is clear and measured, suggesting a reflective and self-improvement context. The recording quality is good, with no noticeable background noise.
#
# File: dialogue_10_utterance_6.wav -> Caption: laion ** caption** A male speaker with a slightly hesitant and self-aware tone is heard. He is discussing his interests and the suspicion of others. The recording quality is clear, with no noticeable background noise. The speaker's voice has a slightly nervous quality, and he seems to be expressing a sense of anxiety.
#
# File: dialogue_16_utterance_13.wav -> Caption: laion ** speaks with a hopeful and encouraging tone. She expresses feeling optimistic about managing anxiety and thanks the listener for helping her with a plan. The recording is clear and sounds like it was made in a quiet environment.
#
# File: dialogue_7_utterance_13.wav -> Caption: laion – caption – A male speaker, with a hopeful and reflective tone, expresses his feelings and thoughts. His voice is clear and calm, and the recording quality is good. He speaks with a moderate pace, and his tone is positive and optimistic.
#
# File: dialogue_10_utterance_1.wav -> Caption: laion ** caption’ A male speaker, with a slightly nervous and hesitant tone, is heard in this recording. He states, “Hi, I’m doing okay thank you. I’m a bit nervous to be honest.” His voice is clear, and the recording quality is good. The speaker sounds like he is trying to be polite, but is also a bit apprehensive.
#
# File: dialogue_12_utterance_7.wav -> Caption: laion ** caption): A male speaker with a slightly melancholic tone is heard, speaking slowly and thoughtfully. He describes an image of himself being alone, and the recording quality is clear.
#
# File: dialogue_16_utterance_14.wav -> Caption: laion ** caption** A male speaker with a friendly and casual tone is heard saying goodbye and mentioning seeing someone next week. The recording quality is clear, with no noticeable background noise. The speaker's voice is relaxed and conversational.
#
# File: dialogue_9_utterance_3.wav -> Caption: laion – caption – A male speaker with a calm and reflective tone is heard. He expresses a feeling of self-awareness, suggesting a sense of personal growth or awareness. The recording quality is good, with no noticeable background noise. His voice is clear and steady, and he speaks at a moderate pace.
#
# File: dialogue_1_utterance_7.wav -> Caption: laion ** caption’s. Her voice is calm and confident, with a hint of self-assurance. The recording is clear and well-balanced, suggesting a professional setup. She speaks with a steady pace, conveying a sense of control and expertise.
#
# File: dialogue_3_utterance_1.wav -> Caption: laion – caption – A female speaker, with a slightly anxious tone, expresses her feelings about an animal shelter. Her voice is clear, and the recording quality is good. She speaks at a moderate pace, and her tone is somewhat reflective and uncomfortable. She mentions her love for going there, but her current avoidance.
#
# File: dialogue_13_utterance_15.wav -> Caption: laion  caption – A male speaker, with a hopeful and slightly upbeat tone, expresses that he feels more hopeful now. The recording is clear, with no noticeable background noise. The speaker's voice is calm and reassuring.
#
# File: dialogue_18_utterance_5.wav -> Caption: laion  caption caption. A male speaker, with a slightly weary tone, expresses concern about the news of the pandemic and travel restrictions. His voice is clear, and the recording quality is good. He speaks with a sense of worry and disappointment.
#
# File: dialogue_2_utterance_12.wav -> Caption: laion ** caption’ A female speaker with a calm and measured tone discusses reactions to different types of emotions. Her voice is clear and steady, suggesting a thoughtful and analytical perspective. The recording quality is good, with no noticeable background noise. She speaks with a sense of objectivity and slight disappointment.
#
# File: dialogue_13_utterance_12.wav -> Caption: laion  caption. The speaker, a male, speaks with a warm and encouraging tone, emphasizing the importance of mutual care and effort in relationships. His voice is clear and sincere, conveying a sense of camaraderie and support. The recording quality is good, with no noticeable background noise.
#
# File: dialogue_18_utterance_2.wav -> Caption: laion  speaks with a calm and somewhat resigned tone, discussing the difficulties of traveling due to restrictions. The recording is clear, with a slight room tone. The speaker's pace is moderate, and the overall feel is conversational.
#
# File: dialogue_2_utterance_15.wav -> Caption: laion ** speaks with a hopeful and determined tone, expressing a willingness to try to get back to doing what she loves. The voice is clear and sincere, conveying a sense of resolve. The recording quality is good, with no noticeable background noise.
#
# File: dialogue_3_utterance_6.wav -> Caption: laion  caption. The female speaker, with a slightly anxious tone, expresses concerns about animals. Her voice is clear, and the recording quality is good. She speaks with a moderate pace, conveying a sense of vulnerability. She seems to be sharing a personal fear.
#
# File: dialogue_7_utterance_4.wav -> Caption: laion ** caption** A male speaker with a calm and slightly hesitant tone is heard. He mentions someone calling his interest in crystals weird and suggesting he focus on normal hobbies. He also states that comments like that make him want to withdraw and not share his passion. The recording quality is clear, with no noticeable background noise.
#
# File: dialogue_5_utterance_2.wav -> Caption: laion! The audio features a male speaker with a slightly hesitant and conversational tone. He is discussing his past interest in crystals, and his voice has a slightly nervous quality. The recording quality is good, with no noticeable background noise. He mentions that he has gotten some negative comments from people about them.
#
# File: dialogue_20_utterance_11.wav -> Caption: laion ** caption’s A male speaker, with a calm and thoughtful tone, is discussing a situation where he is trying to balance fear and hope. His voice is clear and measured, and the recording quality is good. He sounds like he is trying to be rational and rational.
#
# File: dialogue_6_utterance_13.wav -> Caption: laion ** speaks with a somewhat confused and uncertain tone, expressing a feeling of being perceived differently. The recording is clear, with a focus on the speaker's voice.
#
# File: dialogue_3_utterance_8.wav -> Caption: laion. caption’s A female speaker, with a calm and slightly hesitant tone, expresses a logical perspective on animals, stating that they don't really think the same way. Her voice is clear and the recording quality is good. She sounds thoughtful and a bit uncertain.
#
# File: dialogue_1_utterance_9.wav -> Caption: laion. The speaker, a female, expresses uncertainty about the reasons behind someone's behavior, suggesting stress or new staff. Her tone is thoughtful and somewhat speculative. The recording is clear, with no noticeable background noise. She sounds like she is trying to understand something.
#
# File: dialogue_17_utterance_13.wav -> Caption: laion ** caption** A female speaker, with a hopeful and appreciative tone, expresses that she feels more hopeful and that it's nice to talk about something and have ideas to work with. The recording is clear, with no noticeable background noise.
#
# File: dialogue_7_utterance_3.wav -> Caption: laion – caption – A male speaker with a calm and reflective tone describes a personal experience of receiving negative feedback. His voice is clear and steady, suggesting a thoughtful and analytical approach. He speaks with a measured pace, conveying a sense of introspection. The recording quality is good, with no noticeable background noise. He also mentions feeling isolated when discussing personal interests or judgment.
#
# File: dialogue_5_utterance_5.wav -> Caption: laion ** caption): A male speaker with a conversational tone discusses how some friends find something quirky but don't understand it. He mentions that they don't judge him but also don't share the same passion. The recording quality is clear, with no noticeable background noise.
#
# File: dialogue_6_utterance_14.wav -> Caption: laion ** caption): A male speaker, with a slightly hesitant and thoughtful tone, expresses uncertainty about where to begin. His voice is calm and conversational, with a hint of curiosity. The recording quality is clear, with no noticeable background noise. He seems to be contemplating a topic with a touch of uncertainty.
#
# ✅ Results successfully saved to 'emotion_results.json'
